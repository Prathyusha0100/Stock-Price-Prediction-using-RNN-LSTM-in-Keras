# %%
# Time Series Prediction

# %% [markdown]
# Due to the sequential charasteristics of RNNs, they can be used for time series prediction task. A time series is a series of data points indexed in time order. One example of time series is stock prices at regular intervals of time (hourly, daily, etc.). There have been many attempts to forecast stocks market, some belive predicting the market is impossible because of its total random behaviour, while some (mainly stocks technical analysts) belive not 100% accurate, but it is partly predictable, as they say "history repeats itself" (this phrase indicates that there might be some repetitive patterns in market's behaviour).
#
# In this practice, we are going to discover ourselves whether it is possible or not, whether we are going to be rich or broke :)

# %% [markdown]
# Stocks Prediction Using LSTM
# LSTMs can be used for modeling time series (such as stocks market) as they are capable of remembering past information. Stock price prediction is similar to any other machine learning problem where we are given a set of features and we have to predict a corresponding value, in this case our features are the closing prices of stocks in the past 60 days and we want to predict next closing price. We can use LSTM to model this 60 days sequence by a hidden state as we do in all other sequence modeling problems:

# %% [markdown]
# We are going to solve these two following problems:
#
# 1 . Predicting the exact price at time  Ti
#   given prices at times  Ti−60
#  , ...,  Ti−1
#
# 2 . A simplified version of previous problem, predicting the direction of price at time  Ti
#   (whether it is increasing or decreasing) given prices at times  Ti−60
#  , ...,  Ti−1
#
# So the first task is a regression and the second one is a classification problem.

# %% [markdown]
# 1. Predicting The Exact Price
# DATA:
#
# The data that we are going to use are from Yahoo Finance (a place to look up stock market data and company news). We can accsess historical market data from Yahoo Finance using python yfinance module.
#
# Let's install yfinance module first:

# %%
from IPython.display import clear_output

# !pip install yfinance

clear_output()

# %%
import matplotlib.pyplot as plt
import yfinance as yf

train_data = yf.download('AAPL','2014-01-01','2018-01-01')
test_data = yf.download('AAPL','2018-01-01','2019-01-01')

train_data.Close.plot()
test_data.Close.plot()
plt.legend (["Train", "Test"])

clear_output()
plt.show()

# %% [markdown]
# As you can see our data is just a sequence of numbers ordered by time.
#
# In order to normalize our data we scale them between 0 and 1:

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler(feature_range = (0, 1)).fit(train_data.Close.values.reshape(-1, 1))

train_scaled = scaler.transform(train_data.Close.values.reshape(-1, 1))
test_scaled = scaler.transform(test_data.Close.values.reshape(-1, 1))

print ("train_scaled.shape :", train_scaled.shape)
print ("test_scaled.shape :", test_scaled.shape)
# Out:
# train_scaled.shape : (1007, 1)
# test_scaled.shape : (251, 1)

# %% [markdown]
# Now we create our input output pairs from our sequence:

# %%
train_features_set = []
train_labels = []
for i in range(60, train_scaled.shape[0]):
    train_features_set.append(train_scaled[i-60:i, 0])
    train_labels.append(train_scaled[i, 0])

# %% [markdown]
# We need to convert these lists to the numpy arrays before we can use them for training. Then in order to train LSTM on our data, we need to convert our data into the shape accepted by the LSTM. We need to convert our data into three-dimensional format. The first dimension is the number of records or rows in the dataset which is 1007 in our case. The second dimension is the number of time steps which is 60 while the last dimension is the number of indicators. Since we are only using one feature, i.e Closing price, the number of indicators will be one.

# %%
train_features_set, train_labels = np.array(train_features_set), np.array(train_labels)
train_features_set = np.reshape(train_features_set, (train_features_set.shape[0], train_features_set.shape[1], 1))

# %% [markdown]
# Now let's create and train a simple model.
# Define a model that has a stack of 4 lstm layers and a single output layer:

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_features_set.shape[1], 1)))
model.add(Dropout(0.2))

########################################
#     Put your implementation here     #
########################################
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

model.fit(train_features_set, train_labels, epochs = 100, batch_size = 30)

clear_output()

# %% [markdown]
# Now we create our test features set similar to what we did with our training set:

# %%
test_scaled = scaler.transform(test_data.Close.values.reshape(-1, 1))

test_features_set = []
for i in range(60, test_scaled.shape[0]):
    test_features_set.append(test_scaled[i-60:i, 0])

test_features_set = np.array(test_features_set)
test_features_set = np.reshape(test_features_set, (test_features_set.shape[0], test_features_set.shape[1], 1))

# %% [markdown]
# And finaly let's see the results:

# %%
predictions = model.predict(test_features_set)
predictions = scaler.inverse_transform(predictions)

plt.plot(test_data.Close.values[60:], color='blue', label='Actual Apple Stock Price')
plt.plot(predictions , color='red', label='Predicted Apple Stock Price')
plt.title('Apple Stock Price Prediction on Test Set')
plt.ylabel('Apple Stock Price')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 2s 28ms/step

# %% [markdown]
# At first sight, it seems the predictions are following pretty well the actual trend. What do you think about the result? Are you willing to risk using this predictions in real world?
#
# Ans: No, because the trend looks similar to the original data set, the values are way off and at some intervals the curve is flatter compared to the fluctuations in real world.

# %%
Previous model can be evaluated just visually. We can evaluate a classification task using its special measures (such as f-score or accuracy) much better than a regression task. So in order to finaly decide whether the stocks market prediction is practical or not, we define this second task.

Implement a model similar to previous one, this time the task is to predict whether the price is going to increase or decrease (output will be either 1 or 0 respectively) at time  Ti
  given prices at times  Ti−60
 , ...,  Ti−1
  :

# %%
########################################
#     Put your implementation here     #
########################################

#Preparing train data for classification
train_features_set = []
train_labels = []
for i in range(60, train_scaled.shape[0]):
    train_features_set.append(train_scaled[i-60:i, 0])
    if train_scaled[i,0] > train_scaled[i-1, 0]:
      train_labels.append(1)
    else:
      train_labels.append(0)
train_features_set, train_labels = np.array(train_features_set), np.array(train_labels)
train_features_set = np.reshape(train_features_set, (train_features_set.shape[0], train_features_set.shape[1], 1))

# %%
#Preparing test data for classification
test_scaled = scaler.transform(test_data.Close.values.reshape(-1, 1))

test_features_set = []
test_labels = []
for i in range(60, test_scaled.shape[0]):
    test_features_set.append(test_scaled[i-60:i, 0])
    if test_scaled[i,0] > test_scaled[i-1, 0]:
      test_labels.append(1)
    else:
      test_labels.append(0)

test_features_set = np.array(test_features_set)
test_features_set = np.reshape(test_features_set, (test_features_set.shape[0], test_features_set.shape[1], 1))

# %%
#Model for classification
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_features_set.shape[1], 1)))
model.add(Dropout(0.2))

########################################
#     Put your implementation here     #
########################################
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

model.fit(train_features_set, train_labels, epochs = 100, batch_size = 30)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 11s 101ms/step - loss: 0.6934 - accuracy: 0.5153
# Epoch 2/100
# 32/32 [==============================] - 4s 133ms/step - loss: 0.6931 - accuracy: 0.5121
# Epoch 3/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6931 - accuracy: 0.5132
# Epoch 4/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.6924 - accuracy: 0.5206
# Epoch 5/100
# 32/32 [==============================] - 4s 119ms/step - loss: 0.6923 - accuracy: 0.5100
# Epoch 6/100
# 32/32 [==============================] - 4s 111ms/step - loss: 0.6923 - accuracy: 0.5195
# Epoch 7/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 8/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.6937 - accuracy: 0.5216
# Epoch 9/100
# 32/32 [==============================] - 4s 130ms/step - loss: 0.6934 - accuracy: 0.5164
# Epoch 10/100
# 32/32 [==============================] - 3s 103ms/step - loss: 0.6926 - accuracy: 0.5206
# Epoch 11/100
# 32/32 [==============================] - 4s 119ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 12/100
# 32/32 [==============================] - 5s 154ms/step - loss: 0.6920 - accuracy: 0.5185
# Epoch 13/100
# 32/32 [==============================] - 3s 107ms/step - loss: 0.6922 - accuracy: 0.5248
# Epoch 14/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6917 - accuracy: 0.5269
# Epoch 15/100
# 32/32 [==============================] - 3s 108ms/step - loss: 0.6930 - accuracy: 0.4931
# Epoch 16/100
# 32/32 [==============================] - 4s 132ms/step - loss: 0.6930 - accuracy: 0.5058
# Epoch 17/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6921 - accuracy: 0.5216
# Epoch 18/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6921 - accuracy: 0.5216
# Epoch 19/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.6918 - accuracy: 0.5216
# Epoch 20/100
# 32/32 [==============================] - 3s 99ms/step - loss: 0.6923 - accuracy: 0.5111
# Epoch 21/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.6926 - accuracy: 0.5216
# Epoch 22/100
# 32/32 [==============================] - 4s 130ms/step - loss: 0.6923 - accuracy: 0.5100
# Epoch 23/100
# 32/32 [==============================] - 4s 128ms/step - loss: 0.6926 - accuracy: 0.5216
# Epoch 24/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.6920 - accuracy: 0.5227
# Epoch 25/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6915 - accuracy: 0.5269
# Epoch 26/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.6912 - accuracy: 0.5290
# Epoch 27/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6918 - accuracy: 0.5206
# Epoch 28/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.6924 - accuracy: 0.5111
# Epoch 29/100
# 32/32 [==============================] - 3s 107ms/step - loss: 0.6935 - accuracy: 0.5164
# Epoch 30/100
# 32/32 [==============================] - 4s 129ms/step - loss: 0.6915 - accuracy: 0.5227
# Epoch 31/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6919 - accuracy: 0.5164
# Epoch 32/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.6919 - accuracy: 0.5185
# Epoch 33/100
# 32/32 [==============================] - 6s 186ms/step - loss: 0.6917 - accuracy: 0.5132
# Epoch 34/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.6921 - accuracy: 0.5090
# Epoch 35/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.6923 - accuracy: 0.5195
# Epoch 36/100
# 32/32 [==============================] - 4s 126ms/step - loss: 0.6920 - accuracy: 0.5143
# Epoch 37/100
# 32/32 [==============================] - 6s 204ms/step - loss: 0.6925 - accuracy: 0.5195
# Epoch 38/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6926 - accuracy: 0.5195
# Epoch 39/100
# 32/32 [==============================] - 4s 139ms/step - loss: 0.6921 - accuracy: 0.5269
# Epoch 40/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.6919 - accuracy: 0.5238
# Epoch 41/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.6920 - accuracy: 0.5090
# Epoch 42/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.6922 - accuracy: 0.5206
# Epoch 43/100
# 32/32 [==============================] - 5s 154ms/step - loss: 0.6919 - accuracy: 0.5195
# Epoch 44/100
# 32/32 [==============================] - 8s 263ms/step - loss: 0.6920 - accuracy: 0.5048
# Epoch 45/100
# 32/32 [==============================] - 6s 189ms/step - loss: 0.6919 - accuracy: 0.5174
# Epoch 46/100
# 32/32 [==============================] - 3s 105ms/step - loss: 0.6922 - accuracy: 0.5195
# Epoch 47/100
# 32/32 [==============================] - 5s 170ms/step - loss: 0.6917 - accuracy: 0.5206
# Epoch 48/100
# 32/32 [==============================] - 9s 267ms/step - loss: 0.6921 - accuracy: 0.5248
# Epoch 49/100
# 32/32 [==============================] - 8s 246ms/step - loss: 0.6926 - accuracy: 0.5216
# Epoch 50/100
# 32/32 [==============================] - 7s 218ms/step - loss: 0.6912 - accuracy: 0.5227
# Epoch 51/100
# 32/32 [==============================] - 8s 256ms/step - loss: 0.6932 - accuracy: 0.5100
# Epoch 52/100
# 32/32 [==============================] - 3s 105ms/step - loss: 0.6918 - accuracy: 0.5227
# Epoch 53/100
# 32/32 [==============================] - 4s 126ms/step - loss: 0.6919 - accuracy: 0.5290
# Epoch 54/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6913 - accuracy: 0.5227
# Epoch 55/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.6916 - accuracy: 0.5206
# Epoch 56/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.6930 - accuracy: 0.5153
# Epoch 57/100
# 32/32 [==============================] - 4s 134ms/step - loss: 0.6916 - accuracy: 0.5259
# Epoch 58/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.6904 - accuracy: 0.5290
# Epoch 59/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6910 - accuracy: 0.5195
# Epoch 60/100
# 32/32 [==============================] - 4s 121ms/step - loss: 0.6921 - accuracy: 0.5153
# Epoch 61/100
# 32/32 [==============================] - 4s 121ms/step - loss: 0.6913 - accuracy: 0.5280
# Epoch 62/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.6917 - accuracy: 0.5058
# Epoch 63/100
# 32/32 [==============================] - 4s 122ms/step - loss: 0.6924 - accuracy: 0.5280
# Epoch 64/100
# 32/32 [==============================] - 7s 211ms/step - loss: 0.6914 - accuracy: 0.5216
# Epoch 65/100
# 32/32 [==============================] - 7s 204ms/step - loss: 0.6921 - accuracy: 0.5121
# Epoch 66/100
# 32/32 [==============================] - 7s 212ms/step - loss: 0.6919 - accuracy: 0.5227
# Epoch 67/100
# 32/32 [==============================] - 6s 186ms/step - loss: 0.6910 - accuracy: 0.5238
# Epoch 68/100
# 32/32 [==============================] - 7s 204ms/step - loss: 0.6927 - accuracy: 0.5195
# Epoch 69/100
# 32/32 [==============================] - 6s 190ms/step - loss: 0.6911 - accuracy: 0.5206
# Epoch 70/100
# 32/32 [==============================] - 7s 216ms/step - loss: 0.6914 - accuracy: 0.5153
# Epoch 71/100
# 32/32 [==============================] - 4s 129ms/step - loss: 0.6912 - accuracy: 0.5259
# Epoch 72/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6927 - accuracy: 0.5026
# Epoch 73/100
# 32/32 [==============================] - 4s 126ms/step - loss: 0.6923 - accuracy: 0.5121
# Epoch 74/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.6914 - accuracy: 0.5259
# Epoch 75/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.6911 - accuracy: 0.5058
# Epoch 76/100
# 32/32 [==============================] - 4s 134ms/step - loss: 0.6914 - accuracy: 0.5164
# Epoch 77/100
# 32/32 [==============================] - 4s 108ms/step - loss: 0.6902 - accuracy: 0.5037
# Epoch 78/100
# 32/32 [==============================] - 3s 103ms/step - loss: 0.6912 - accuracy: 0.5343
# Epoch 79/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.6905 - accuracy: 0.5312
# Epoch 80/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.6919 - accuracy: 0.5058
# Epoch 81/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.6906 - accuracy: 0.5227
# Epoch 82/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.6906 - accuracy: 0.5280
# Epoch 83/100
# 32/32 [==============================] - 4s 119ms/step - loss: 0.6916 - accuracy: 0.5111
# Epoch 84/100
# 32/32 [==============================] - 4s 121ms/step - loss: 0.6916 - accuracy: 0.5132
# Epoch 85/100
# 32/32 [==============================] - 3s 103ms/step - loss: 0.6909 - accuracy: 0.5290
# Epoch 86/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6923 - accuracy: 0.5185
# Epoch 87/100
# 32/32 [==============================] - 4s 132ms/step - loss: 0.6915 - accuracy: 0.5206
# Epoch 88/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6912 - accuracy: 0.5121
# Epoch 89/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.6903 - accuracy: 0.5185
# Epoch 90/100
# 32/32 [==============================] - 4s 116ms/step - loss: 0.6903 - accuracy: 0.5259
# Epoch 91/100
# 32/32 [==============================] - 4s 119ms/step - loss: 0.6906 - accuracy: 0.5438
# Epoch 92/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.6900 - accuracy: 0.5354
# Epoch 93/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.6903 - accuracy: 0.5364
# Epoch 94/100
# 32/32 [==============================] - 4s 134ms/step - loss: 0.6902 - accuracy: 0.5417
# Epoch 95/100
# 32/32 [==============================] - 3s 97ms/step - loss: 0.6901 - accuracy: 0.5248
# Epoch 96/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.6904 - accuracy: 0.5301
# Epoch 97/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.6890 - accuracy: 0.5269
# Epoch 98/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.6906 - accuracy: 0.5238
# Epoch 99/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6892 - accuracy: 0.5385
# Epoch 100/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6889 - accuracy: 0.5417

# %% [markdown]
# Evaluate your trained model using the test set and report accuracy and f1-score your model archived:

# %%
########################################
#     Put your implementation here     #
########################################

# Calculating the Metrics
from sklearn.metrics import accuracy_score, f1_score
y_pred = (model.predict(test_features_set) > 0.5).astype(int)
accuracy = accuracy_score(test_labels, y_pred)
f1 = f1_score(test_labels, y_pred)
# Out:
# 6/6 [==============================] - 2s 28ms/step

# %%
print(accuracy, f1)
# Out:
# 0.5340314136125655 0.6962457337883959

# %% [markdown]
# Do not worry if your results are not as promising as before :))
#
# Comparing new results with previuos ones, why do you think this happens? Doesn't this task supposed to be an easier version of the previous one (if you are able to predict the actual price, you are already able to predict the direction of price trend)? Explain your toughts:
#
# Ans: If we look at the graph above, the predicted curve did not have as many fluctuations as the real curve had. We may get values of stock that could imitate the trend as a whole but given a time point predicting the direction takes comparison to each and every point. If we look at the above curve, it is not fluctuating as much as the real curve so getting directions from that will lead to many errors and less accuracy just like we had in this model.
